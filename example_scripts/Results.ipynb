# %%
# !git clone https://github.com/kailasdayanandan/dual_thinking.git
# Out:
# Cloning into 'dual_thinking'...
# remote: Enumerating objects: 218, done.
# remote: Counting objects: 100% (72/72), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 218 (delta 65), reused 46 (delta 46), pack-reused 146 (from 2)
# Receiving objects: 100% (218/218), 42.55 MiB | 9.28 MiB/s, done.
# Resolving deltas: 100% (99/99), done.
# Updating files: 100% (32/32), done.

# %%
import os
# %cd dual_thinking/data
os.makedirs('human-confusion-dataset.0.4', exist_ok=True)
# %cd human-confusion-dataset.0.4
# !wget https://github.com/kailasdayanandan/dual_thinking/releases/download/v0.0.4-dataset-release/human-confusion-dataset.0.4.zip
# Out:
# /content/dual_thinking/data
# /content/dual_thinking/data/human-confusion-dataset.0.4
# --2025-09-01 07:11:24--  https://github.com/kailasdayanandan/dual_thinking/releases/download/v0.0.4-dataset-release/human-confusion-dataset.0.4.zip
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !unzip -o -q human-confusion-dataset.0.4.zip

# %%
# %cd human-confusion-dataset.0.4
# !mv * ../
# %cd ../../
# Out:
# /content/dual_thinking

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
# !python /content/dual_thinking/main_release.py
# Out:
# 13762 ['model', 'filename', 'Correct', 'Human', 'Error']
# 10813 ['model', 'filename', 'Correct', 'Human', 'Error']
# 24575 ['model', 'filename', 'Correct', 'Human', 'Error']
# ------------------------------------------------------------
# SubGroup files :  984
# Annotations :  ['filename', 'Figure Ground', 'Proximity', 'Similarity', 'Continuity', 'Amodal', 'Global Mix', 'Size Diff', 'Count Diff', 'Camouflage']
# ------------------------------------------------------------
# Model processed files :  983
# ============================================================ Figure Ground ============================================================
#                Model  Correct  Human  Error
# 14            GPT-4o     0.88   0.12   0.01
# 18                o3     0.86   0.13   0.01
# 17     Llama-3.2-90B     0.77   0.22   0.02
# 22  gemini-2.0-flash     0.76   0.24   0.01
# 24      deepseek-vl2     0.73   0.26   0.01
# 15       GPT-4o-mini     0.73   0.27   0.01
# ...

# %%
image = mpimg.imread("output/plots/box.png")
fig = plt.figure(figsize=(15, 15))
plt.axis('off')
plt.imshow(image)
plt.show()

# %%
image = mpimg.imread("output/plots/human_box.png")
fig = plt.figure(figsize=(15, 15))
plt.axis('off')
plt.imshow(image)
plt.show()

# %%
image = mpimg.imread("output/plots/models_all_stacked.png")
fig = plt.figure(figsize=(15, 15))
plt.axis('off')
plt.imshow(image)
plt.show()
